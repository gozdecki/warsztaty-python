# %% [markdown]
# Loadind data in two column format

# %%
f= open('reference.csv')

# %%
lista=[1,2,3,4]

# %%
lista[0]
# Out:
# 1

# %%
for element in lista:
    print(element)
# Out:
# 1
# 2
# 3
# 4
# 10
# 10

# %%
lista.append(10)

# %%
lista[5]
# Out:
# 10

# %%
linijka='800,34.25'

# %%
res = linijka.split(',')

# %%
res
# Out:
# ['800', '34.25']

# %%
float(res[1])
# Out:
# 34.25

# %%
x=[]
y=[]
for line in open('reference.csv'):
    res=line.split(',')
    x.append(float(res[0]))
    y.append(float(res[1]))
#print(x,y)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.show()

# %%
plt.savefig("fig")
